# %%
import pandas as pd

# %%
df = pd.read_csv("data/sample_data.csv")
df.head()
# Out:
#       category                              text
# 0   Sanitation  Garbage not collected for 3 days
# 1  Electricity     Street lights are not working
# 2        Water     No water supply since morning
# 3        Roads    Big potholes causing accidents
# 4   Sanitation       Bad smell from garbage area

# %%
df.shape
# Out:
# (8, 2)

# %%
df.columns
# Out:
# Index(['category', 'text'], dtype='object')

# %%
def clean_text(text):
    return text.lower()

# %%
df['clean_text']=df['text'].apply(clean_text)

# %%
df.head()
# Out:
#       category                              text  \
# 0   Sanitation  Garbage not collected for 3 days
# 1  Electricity     Street lights are not working
# 2        Water     No water supply since morning
# 3        Roads    Big potholes causing accidents
# 4   Sanitation       Bad smell from garbage area
#
#                          clean_text
# 0  garbage not collected for 3 days
# 1     street lights are not working
# 2     no water supply since morning
# 3    big potholes causing accidents
# 4       bad smell from garbage area

# %%
import re

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-zA-Z\s]","",text)
    return text

# %%
df['clean_text'] = df['text'].apply(clean_text)

# %%
df.head()
# Out:
#       category                              text  \
# 0   Sanitation  Garbage not collected for 3 days
# 1  Electricity     Street lights are not working
# 2        Water     No water supply since morning
# 3        Roads    Big potholes causing accidents
# 4   Sanitation       Bad smell from garbage area
#
#                         clean_text
# 0  garbage not collected for  days
# 1    street lights are not working
# 2    no water supply since morning
# 3   big potholes causing accidents
# 4      bad smell from garbage area

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 import nltk
#       2 from nltk.corpus import stopwords
#       3 from nltk.tokenize import word_tokenize
#
# ModuleNotFoundError: No module named 'nltk'
